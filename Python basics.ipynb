# %%
# data types in python
# Int
print(-1273984)
print(0)
print(193701)

# Float
print(-12739.84)
print(0.0)
print(1937.01)

# Bool
print(True)
print(False)


# String
print('Ashish')
print('A')
print('print()')
# print
print("Ashish" , "Jangra", 12, True, 12.5)
print('-', end = "\n\t")
print('*')
print('______')

# Checking the datatype

print(type(-42341))
print(type(0))
print(type(42341))
print("* * * * * * *")

print(type(-423.41))
print(type(0.0))
print(type(42.341))
print("* * * * * * *")

print(type("A"))
print(type("Ashish"))
print(type("Asf dskjfh kjsdhfkj hsdkf hsdkhfk"))
print(type("01/10/2025"))
print(type("10:25"))
print("* * * * * * *")

print(type(True))
print(type("True"))
#Arithmetic Operators
print(12 + 34 + 44 )
print(12 - 34)
print(13 * 4)
print(12 / 4)
print(12 // 4)
print(12 % 4)
print(12 ** 4)

print('A' + 'B' + '\n\t' + 'Dgfsdakg fkhjsad')
print('-' * 30)

print(True * False)
print((True * False)*5)
print(((True * False)*5)*'Ashish', end = "")
print('A'*0, end = "")
print('-')

# Comparison
age = 19

print(age > 18)
print(age >= 18)
print(age < 18)
print(age <= 18)
print(age == 18)
print(age != 18)

print(True == 1.0)
# logical
print((age >= 18) and (age <= 100))
print((age >= 18) or (age <= 100))
print(not (age <= 100))
print('-'*20)

# typecasting
# int()
print(int(3.5), int(-3.5), int('-1476476'), int(True))


# float()
print(float(3), float(-3), float('-1476476'), float(True))

# str()
print(str(3), str(-3), str(3.5), str(True))

# bool()
print(bool(3), bool(-3), bool(3.5), bool('A'), bool(' '), bool(0), bool(0.0), bool(''))

# Condition based
# age = 18

if (age >= 18) and (age <= 100):
    print('eligible')

elif (age >= 0) and (age < 18):
    print('not eligible')

else:
    print('not a valid age')


number = 15

#q1
if (number%5 == 0):
    print('divisible by 5')
else:
    print('not divisible by 5')


#q2
if (number%5 == 0) and (number%7 == 0):
    print('divisible by 5 and 7')
else:
    print('not divisible by 5 and 7')


#q3
if (number%5 == 0) and (number%7 == 0) and (number%13 != 0):
    print('divisible by 5 and 7 but not 13')
else:
    print('~()')



#q4
n = 35

if (n%5 == 0) and (n%7 == 0):
    print('divisible by 5 and 7 both')

elif (n%5 == 0) and (n%7 != 0):
    print('5 not 7')

elif (n%5 != 0) and (n%7 == 0):
    print('7 not 5')

elif (n%5 != 0) and (n%7 != 0):
    print('not 5 not 7')






n = 10

if n%5 == 0:
    if n%7 == 0:
        if n%13 == 0:
            print('5,7,13')
        else:
            print('5, 7 not 13')
    else:
        print('5, not 7')

elif n%7 == 0:
    if n%13 == 0:
        print('7,13 not 5')
    else:
        print('7 not 13 not 5')

else:
    print('not 5 not 7 not 13')
# Out:
# -1273984
# 0
# 193701
# -12739.84
# 0.0
# 1937.01
# True
# False
# Ashish
# A
# print()
# Ashish Jangra 12 True 12.5
# -
# 	*
# ______
# <class 'int'>
# <class 'int'>
# <class 'int'>
# * * * * * * *
# <class 'float'>
# <class 'float'>
# <class 'float'>
# * * * * * * *
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# * * * * * * *
# <class 'bool'>
# <class 'str'>
# 90
# -22
# 52
# 3.0
# 3
# 0
# 20736
# AB
# 	Dgfsdakg fkhjsad
# ------------------------------
# 0
# 0
# -
# True
# True
# False
# False
# False
# True
# True
# True
# True
# False
# --------------------
# 3 -3 -1476476 1
# 3.0 -3.0 -1476476.0 1.0
# 3 -3 3.5 True
# True True True True True False False False
